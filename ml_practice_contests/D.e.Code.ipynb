# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv('investmentsData.csv')

# %%
d1.head(3)
# Out:
#    Advisor_Id  Investment_Id     Date      Morningstar Category  Rating  \
# 0      989994         120816  2017-01  US Fund Target-Date 2040     3.0
# 1      990003         120816  2017-01  US Fund Target-Date 2040     3.0
# 2      990003         120816  2017-02  US Fund Target-Date 2040     2.0
#
#    1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  10 Yr % Rank  1 Yr Return  \
# 0          5.0         67.0         60.0           NaN      5.26691
# 1          5.0         67.0         60.0           NaN      5.26691
# 2          5.0         77.0         91.0           NaN      7.59688
#
#          ...          Net Flows  Activity_Type  Activity_Count  Code_1 Code_2  \
# 0        ...         25470973.0            NaN             NaN      85     11
# 1        ...         25470973.0            NaN             NaN     101     98
# 2        ...         49045870.0            NaN             NaN     101     36
#
#    Code_3  Code_4  Code_5    Amount  Transaction_Type
# ...

# %%
d1.describe()
# Out:
#          Advisor_Id  Investment_Id         Rating    1 Yr % Rank  \
# count  6.381010e+05  638101.000000  624933.000000  624935.000000
# mean   8.623147e+05  119533.744321       1.958445       6.047231
# std    2.172654e+05    4060.806983       0.874138       8.400080
# min   -9.039000e+03  104157.000000       1.000000       2.000000
# 25%    7.218290e+05  120816.000000       1.000000       4.000000
# 50%    9.501330e+05  120816.000000       2.000000       4.000000
# 75%    1.030025e+06  120816.000000       2.000000       5.000000
# max    1.114749e+06  122057.000000       5.000000      99.000000
#
#          3 Yr % Rank    5 Yr % Rank  10 Yr % Rank    1 Yr Return  \
# count  624933.000000  624908.000000  24128.000000  624935.000000
# mean       67.174774      84.731071     16.472231       9.526124
# std        20.898708      20.451041      9.313590       4.109108
# min         9.000000      11.000000      1.000000     -16.878466
# ...

# %%
list(d1)
# Out:
# ['Advisor_Id',
#  'Investment_Id',
#  'Date',
#  'Morningstar Category',
#  'Rating',
#  '1 Yr % Rank',
#  '3 Yr % Rank',
#  '5 Yr % Rank',
#  '10 Yr % Rank',
#  '1 Yr Return',
#  '3 Yr Return',
#  '5 Yr Return',
#  '10 Yr Return',
#  'Net Flows',
#  'Activity_Type',
#  'Activity_Count',
#  'Code_1',
#  'Code_2',
#  'Code_3',
#  'Code_4',
#  'Code_5',
#  'Amount',
#  'Transaction_Type']

# %%
set(d1['Morningstar Category'])
# Out:
# {nan,
#  'US Fund Commodities Broad Basket',
#  'US Fund Diversified Emerging Mkts',
#  'US Fund Europe Stock',
#  'US Fund Global Real Estate',
#  'US Fund Health',
#  'US Fund Large Value',
#  'US Fund Multialternative',
#  'US Fund Real Estate',
#  'US Fund Target-Date 2040',
#  'US Fund Target-Date 2050'}

# %%
d1['Activity_Count']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        6.0
# 15        6.0
# 16        6.0
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#          ...
# 638071    NaN
# 638072    NaN
# 638073    NaN
# 638074    NaN
# 638075    9.0
# 638076    9.0
# 638077    9.0
# 638078    9.0
# 638079    6.0
# 638080    6.0
# 638081    6.0
# 638082    6.0
# 638083    6.0
# 638084    NaN
# 638085    NaN
# 638086    NaN
# 638087    NaN
# 638088    NaN
# 638089    NaN
# 638090    NaN
# 638091    NaN
# 638092    NaN
# 638093    NaN
# 638094    NaN
# 638095    NaN
# 638096    NaN
# 638097    3.0
# 638098    3.0
# 638099    NaN
# 638100    NaN
# ...

# %%
d1.shape
# Out:
# (638101, 23)

# %%
d1[d1['Transaction_Type']==1].shape
# Out:
# (265618, 23)

# %%
#not that much unbalanced

# %%
d1['10 Yr Return'].describe()
# Out:
# count    24128.000000
# mean         3.857443
# std          0.764058
# min          2.481637
# 25%          3.194765
# 50%          3.973547
# 75%          4.228893
# max          9.197889
# Name: 10 Yr Return, dtype: float64

# %%
d1[d1['10 Yr Return'].isnull()].shape
# Out:
# (613973, 23)

# %%
d1[d1['10 Yr % Rank'].isnull()].shape
# Out:
# (613973, 23)

# %%
d1=d1.drop('10 Yr % Rank',1)

d1=d1.drop('10 Yr Return',1)

# %%
for column in d1.columns:
    print(column)
    print(d1[d1[column].isnull()].shape)
# Out:
# Advisor_Id
# (0, 21)
# Investment_Id
# (0, 21)
# Date
# (0, 21)
# Morningstar Category
# (13166, 21)
# Rating
# (13168, 21)
# 1 Yr % Rank
# (13166, 21)
# 3 Yr % Rank
# (13168, 21)
# 5 Yr % Rank
# (13193, 21)
# 1 Yr Return
# (13166, 21)
# 3 Yr Return
# (13168, 21)
# 5 Yr Return
# (13193, 21)
# Net Flows
# (13166, 21)
# Activity_Type
# (393836, 21)
# Activity_Count
# (393836, 21)
# Code_1
# (0, 21)
# Code_2
# (0, 21)
# Code_3
# (0, 21)
# Code_4
# (0, 21)
# Code_5
# (0, 21)
# Amount
# (0, 21)
# Transaction_Type
# (0, 21)

# %%
d1['Activity_Type'].dtype
# Out:
# dtype('O')

# %%
d1['Activity_Type'].head(50)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14       26
# 15    22,26
# 16    22,26
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      NaN
# Name: Activity_Type, dtype: object

# %%
#creating unique activity type columns

# %%
dummy=d1['Activity_Type'].str.split(',',expand=True)

# %%
unique_categories=set(dummy[0])|set(dummy[1])|set(dummy[2])|set(dummy[3])|set(dummy[4])

# %%
# adding columns

# %%
unique_categories=list(unique_categories)

# %%
for element in unique_categories:
    d1[element]=np.nan

# %%
d1.shape
# Out:
# (638101, 43)

# %%
list(d1)
# Out:
# ['Advisor_Id',
#  'Investment_Id',
#  'Date',
#  'Morningstar Category',
#  'Rating',
#  '1 Yr % Rank',
#  '3 Yr % Rank',
#  '5 Yr % Rank',
#  '1 Yr Return',
#  '3 Yr Return',
#  '5 Yr Return',
#  'Net Flows',
#  'Activity_Type',
#  'Activity_Count',
#  'Code_1',
#  'Code_2',
#  'Code_3',
#  'Code_4',
#  'Code_5',
#  'Amount',
#  'Transaction_Type',
#  nan,
#  '30',
#  '22',
#  '26',
#  '27',
#  '11',
#  '25',
#  '13',
#  '12',
#  '14',
#  '17',
#  '16',
#  '19',
#  '18',
#  '23',
#  '1',
#  '2',
#  '5',
#  '4',
#  '7',
#  '6',
#  '9']

# %%
for row in d1.index:
    for elements in unique_categories:
        if(row%100==0):
            print('done')
        if elements in str(d1.loc[row,'Activity_Type']).split(','):
                d1.loc[row,elements]=1
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
d1.head()
# Out:
#    Advisor_Id  Investment_Id     Date      Morningstar Category  Rating  \
# 0      989994         120816  2017-01  US Fund Target-Date 2040     3.0
# 1      990003         120816  2017-01  US Fund Target-Date 2040     3.0
# 2      990003         120816  2017-02  US Fund Target-Date 2040     2.0
# 3      990003         120816  2017-03  US Fund Target-Date 2040     1.0
# 4      990003         120816  2017-04  US Fund Target-Date 2040     1.0
#
#    1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return ...  19  \
# 0          5.0         67.0         60.0     5.266910     6.034646 ... NaN
# 1          5.0         67.0         60.0     5.266910     6.034646 ... NaN
# 2          5.0         77.0         91.0     7.596880     5.414178 ... NaN
# 3          4.0         92.0         95.0    11.994344     5.192679 ... NaN
# 4          5.0         80.0         97.0    14.809882     4.827860 ... NaN
#
#    18  23   1   2   5   4   7   6   9
# 0 NaN NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %%
d1.tail()
# Out:
#         Advisor_Id  Investment_Id     Date      Morningstar Category  Rating  \
# 638096      989981         120821  2017-03  US Fund Target-Date 2050     1.0
# 638097      989981         120821  2017-04  US Fund Target-Date 2050     1.0
# 638098      989981         120816  2017-04  US Fund Target-Date 2040     1.0
# 638099      989981         120821  2017-05  US Fund Target-Date 2050     1.0
# 638100      989981         120816  2017-05  US Fund Target-Date 2040     2.0
#
#         1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return ...  \
# 638096          2.0         70.0         86.0    14.510998     6.784406 ...
# 638097          2.0         25.0         91.0    17.987189     6.430018 ...
# 638098          5.0         80.0         97.0    14.809882     4.827860 ...
# 638099          2.0         21.0         88.0    10.992739     4.668921 ...
# 638100          4.0         68.0         96.0     9.110319     3.367922 ...
#
# ...

# %%
list(d1)
# Out:
# ['Advisor_Id',
#  'Investment_Id',
#  'Date',
#  'Morningstar Category',
#  'Rating',
#  '1 Yr % Rank',
#  '3 Yr % Rank',
#  '5 Yr % Rank',
#  '1 Yr Return',
#  '3 Yr Return',
#  '5 Yr Return',
#  'Net Flows',
#  'Activity_Type',
#  'Activity_Count',
#  'Code_1',
#  'Code_2',
#  'Code_3',
#  'Code_4',
#  'Code_5',
#  'Amount',
#  'Transaction_Type',
#  nan,
#  '30',
#  '22',
#  '26',
#  '27',
#  '11',
#  '25',
#  '13',
#  '12',
#  '14',
#  '17',
#  '16',
#  '19',
#  '18',
#  '23',
#  '1',
#  '2',
#  '5',
#  '4',
#  '7',
#  '6',
#  '9']

# %%
d1['11'].value_counts
# Out:
# <bound method Series.value_counts of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 638071   NaN
# 638072   NaN
# 638073   NaN
# 638074   NaN
# 638075   NaN
# 638076   NaN
# 638077   NaN
# 638078   NaN
# 638079   NaN
# 638080   NaN
# 638081   NaN
# 638082   NaN
# 638083   NaN
# 638084   NaN
# 638085   NaN
# 638086   NaN
# 638087   NaN
# 638088   NaN
# 638089   NaN
# 638090   NaN
# 638091   NaN
# 638092   NaN
# 638093   NaN
# 638094   NaN
# 638095   NaN
# 638096   NaN
# 638097   NaN
# 638098   NaN
# 638099   NaN
# 638100   NaN
# Name: 11, dtype: float64>

# %%
type(d1['11'])
# Out:
# pandas.core.series.Series

# %%
d1['11'].dtype
# Out:
# dtype('float64')

# %%
#fix a boosting model

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-87-dbe785ce6520> in <module>()
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.model_selection import GridSearchCV
#       3
#       4 from sklearn.metrics import classification_report
#
# ImportError: No module named model_selection

# %%
submit=pd.read_csv("samplesubmission.csv")

# %%
# preapre the submission data

# %%
imp_col=['Morningstar Category',
 'Rating',
 '1 Yr % Rank',
 '3 Yr % Rank',
 '5 Yr % Rank',
 '1 Yr Return',
 '3 Yr Return',
 '5 Yr Return',
 'Net Flows',
 'Activity_Type',
 'Activity_Count',
 'Code_1',
 'Code_2',
 'Code_3',
 'Code_4',
 'Code_5',
 'Amount',
 'Transaction_Type',
 '11',
 '25',
 '13',
 '12',
 '14',
 '17',
 '16',
 '19',
 '18',
 '30',
 '22',
 '26',
 '1',
 '27',
 '5',
 '4',
 '7',
 '6',
 '9',
 '2',
 '23']

# %%
d1.fillna(0,inplace=True)

# %%
for column in imp_col:
    submit[column]=np.nan

# %%
for column in imp_col:
    submit[column]=submit[column].map(d1.set_index('Advisor_Id')[column])
    print("one column done")
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-115-6d5ee4352d8c> in <module>()
#       1 for column in imp_col:
# ----> 2     submit[column]=submit[column].map(d1.set_index('Advisor_Id')[column])
#       3     print("one column done")
#       4
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in map(self, arg, na_action)
#    2114                 arg = self._constructor(arg, index=arg.keys())
#    2115
# -> 2116             indexer = arg.index.get_indexer(values)
#    2117             new_values = com.take_1d(arg._values, indexer)
#    2118             return self._constructor(new_values,
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_indexer(self, target, method, limit, tolerance)
#    2008             target = target.astype(object)
# ...

# %%
d2['Advisor_Id']
# Out:
# 5113       992412
# 5114       992412
# 5115       992412
# 5783       992742
# 5803       992742
# 8622       994054
# 8623       994054
# 11748      995416
# 11754      995416
# 11829      995444
# 11830      995444
# 11831      995444
# 14586      996635
# 14588      996635
# 14590      996635
# 14591      996635
# 14593      996635
# 14594      996635
# 14595      996635
# 25471     1001511
# 30584     1003188
# 30588     1003188
# 30590     1003188
# 31867     1003787
# 33488     1004436
# 33489     1004436
# 33491     1004436
# 47653     1010354
# 49380     1011367
# 49383     1011367
#            ...
# 618119     981617
# 618121     981617
# 618123     981617
# 618125     981617
# 618126     981617
# 618132     981617
# 618133     981617
# 618137     981617
# 618138     981617
# 619610     982114
# 619611     982114
# 623577     983718
# 623578     983718
# 623581     983718
# 623584     983718
# 623585     983718
# 623588     983718
# 627537     985406
# 627542     985406
# ...

# %%
#how the variables are related with time

# %%
d1["time"] = (pd.to_datetime(d1["Date"], format="%Y-%m"))

# %%
d1["Month"] = d1["time"].apply(lambda x: x.month)

# %%
d1["Year"] = d1["time"].apply(lambda x: x.year)

# %%
#plotting the feature values with respect to  time axis

# %%
#Activity_type column vs time axis

# %%
data=d1[:25000]

# %%
data.set_index('Date',inplace=True)

# %%
import matplotlib
matplotlib.use('Agg') # Must be before importing matplotlib.pyplot or pylab!
import matplotlib.pyplot as plt

# %%
#data.set_index(['time'],inplace=True)

plt.plot(data.index, data['5'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-64-4a6366aa3e2a> in <module>()
#       1 #data.set_index(['time'],inplace=True)
#       2
# ----> 3 plt.plot(data.index, data['5'])
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3145 @_autogen_docstring(Axes.plot)
#    3146 def plot(*args, **kwargs):
# -> 3147     ax = gca()
#    3148     # allow callers to override the hold state by passing hold=True|False
#    3149     washold = ax.ishold()
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     926     matplotlib.figure.Figure.gca : The figure's gca method.
#     927     """
# --> 928     return gcf().gca(**kwargs)
#     929
#     930 # More ways of creating axes:
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gcf()
# ...

# %%
df.plot(x='Date', y='5')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-8497a502c208> in <module>()
# ----> 1 df.plot(x='Date', y='5')
#       2 plt.show()
#
# /home/adarshbug/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3735                           fontsize=fontsize, colormap=colormap, table=table,
#    3736                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3737                           sort_columns=sort_columns, **kwds)
#    3738     __call__.__doc__ = plot_frame.__doc__
#    3739
#
# ...

# %%
d2=d1[d1['Investment_Id']==104157]

# %%
d2['Month']
# Out:
# 5113      1
# 5114      4
# 5115      4
# 5783      3
# 5803      6
# 8622      1
# 8623      3
# 11748     3
# 11754     6
# 11829     2
# 11830     4
# 11831     5
# 14586     1
# 14588     3
# 14590     4
# 14591     4
# 14593     5
# 14594     5
# 14595     6
# 25471     1
# 30584     2
# 30588     4
# 30590     6
# 31867     5
# 33488     1
# 33489     3
# 33491     4
# 47653     5
# 49380     3
# 49383     5
#          ..
# 618119    1
# 618121    2
# 618123    3
# 618125    4
# 618126    4
# 618132    5
# 618133    5
# 618137    6
# 618138    6
# 619610    1
# 619611    6
# 623577    1
# 623578    2
# 623581    3
# 623584    5
# 623585    5
# 623588    6
# 627537    1
# 627542    5
# 627545    6
# 627546    6
# 627547    6
# 630453    5
# 631494    3
# 631495    4
# 631496    6
# 633605    3
# 633606    5
# 636934    3
# 636935    3
# Name: Month, dtype: int64

# %%
d1[d1['5 Yr % Rank']==0].shape
# Out:
# (13193, 46)

# %%
d1.shape
# Out:
# (638101, 46)

# %%
d1[d1['1 Yr % Rank']==0].shape
# Out:
# (13166, 46)

# %%
d1[d1['3 Yr % Rank']==0].shape
# Out:
# (13168, 46)

# %%
d2['Amount']
# Out:
# 5113      -78693.960
# 5114       98418.600
# 5115      -26472.040
# 5783     -135796.933
# 5803      -79421.853
# 8622     -344692.013
# 8623     -773263.000
# 11748      22449.853
# 11754      76328.920
# 11829       -142.907
# 11830       1233.813
# 11831      -1416.920
# 14586       8030.347
# 14588       6885.453
# 14590       4809.840
# 14591      -1605.187
# 14593       8266.547
# 14594      -2781.480
# 14595      -8845.853
# 25471     -11614.240
# 30584     -10338.973
# 30588      -1622.667
# 30590       3710.280
# 31867       7398.293
# 33488     -91948.973
# 33489     -19212.973
# 33491     104538.560
# 47653      10883.093
# 49380       4547.533
# 49383       3990.333
#              ...
# 618119    167252.653
# 618121     14135.187
# 618123      5896.053
# 618125   -154411.360
# 618126    640155.787
# 618132   -108646.720
# 618133    477676.173
# 618137     11915.080
# 618138    -10120.240
# 619610     29476.813
# 619611    -25460.333
# 623577    -45410.587
# ...

# %%
d2.shape
# Out:
# (382, 46)

# %%
d2.groupby('Month').count()
# Out:
#        Advisor_Id  Investment_Id  Date  Morningstar Category  Rating  \
# Month
# 1              70             70    70                    70      70
# 2              55             55    55                    55      55
# 3              61             61    61                    61      61
# 4              68             68    68                    68      68
# 5              62             62    62                    62      62
# 6              66             66    66                    66      66
#
#        1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return  ...   \
# Month                                                                   ...
# 1               70           70           70           70           70  ...
# 2               55           55           55           55           55  ...
# 3               61           61           61           61           61  ...
# 4               68           68           68           68           68  ...
# ...

# %%
d2.shape
# Out:
# (382, 46)

# %%
d1.groupby('Month').count()
# Out:
#        Advisor_Id  Investment_Id    Date  Morningstar Category  Rating  \
# Month
# 1          103515         103515  103515                103515  103515
# 2          103307         103307  103307                103307  103307
# 3          106822         106822  106822                106822  106822
# 4          110192         110192  110192                110192  110192
# 5          105807         105807  105807                105807  105807
# 6          108458         108458  108458                108458  108458
#
#        1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return  \
# Month
# 1           103515       103515       103515       103515       103515
# 2           103307       103307       103307       103307       103307
# 3           106822       106822       106822       106822       106822
# 4           110192       110192       110192       110192       110192
# 5           105807       105807       105807       105807       105807
# ...

# %%
d1.groupby('Investment_Id').count()
# Out:
#                Advisor_Id    Date  Morningstar Category  Rating  1 Yr % Rank  \
# Investment_Id
# 104157                382     382                   382     382          382
# 105561              17867   17867                 17867   17867        17867
# 105564                  9       9                     9       9            9
# 105657                  4       4                     4       4            4
# 105805                146     146                   146     146          146
# 106020               6241    6241                  6241    6241         6241
# 106023               8950    8950                  8950    8950         8950
# 106364               2794    2794                  2794    2794         2794
# 106366              10593   10593                 10593   10593        10593
# 108091               1770    1770                  1770    1770         1770
# 110843                  2       2                     2       2            2
# ...

# %%
len(set(d2['Advisor_Id']))
# Out:
# 132

# %%
len(set(d1['Investment_Id']))
# Out:
# 24

# %%
len(set(d1['Advisor_Id']))
# Out:
# 105289

# %%
#preparing columns w.r.t. invester id

# %%
df2 = d1.reset_index().drop_duplicates(subset='Investment_Id').set_index('Investment_Id')

# %%
#preparing columns w.r.t. advisor id

# %%
df2.shape
# Out:
# (24, 46)

# %%
set()

# %%
df3 = d1.reset_index().drop_duplicates(subset='Advisor_Id').set_index('Advisor_Id')

# %%
# Code_x variables w.r.t. the advisor id and the return e.t.c. are w.r.t. the investment id and activity_type amy be time dependent

# %%
df3.shape
# Out:
# (105289, 46)

# %%
list(d1)
# Out:
# ['Advisor_Id',
#  'Investment_Id',
#  'Date',
#  'Morningstar Category',
#  'Rating',
#  '1 Yr % Rank',
#  '3 Yr % Rank',
#  '5 Yr % Rank',
#  '1 Yr Return',
#  '3 Yr Return',
#  '5 Yr Return',
#  'Net Flows',
#  'Activity_Type',
#  'Activity_Count',
#  'Code_1',
#  'Code_2',
#  'Code_3',
#  'Code_4',
#  'Code_5',
#  'Amount',
#  'Transaction_Type',
#  nan,
#  '30',
#  '22',
#  '26',
#  '27',
#  '11',
#  '25',
#  '13',
#  '12',
#  '14',
#  '17',
#  '16',
#  '19',
#  '18',
#  '23',
#  '1',
#  '2',
#  '5',
#  '4',
#  '7',
#  '6',
#  '9',
#  'time',
#  'Month',
#  'Year']

# %%
Investment_id_based_features=['1 Yr % Rank',
 '3 Yr % Rank',
 '5 Yr % Rank',
 '1 Yr Return',
 '3 Yr Return',
 '5 Yr Return']

# %%
Advisor_Id_based_features=['Code_1',
 'Code_2',
 'Code_3',
 'Code_4',
 'Code_5']

# %%
submit=pd.read_csv('samplesubmission.csv')

# %%
df2=df2.drop('Morningstar Category',1)

# %%
list(submit)
# Out:
# ['Advisor_Id', 'Investment_Id', 'Transaction_Type']

# %%
for element in Investment_id_based_features:
    submit[element]=np.nan

# %%
submit.head()
# Out:
#    Advisor_Id  Investment_Id  Transaction_Type  1 Yr % Rank  3 Yr % Rank  \
# 0      990003         120816               NaN          NaN          NaN
# 1      990007         120821               NaN          NaN          NaN
# 2      990009         120816               NaN          NaN          NaN
# 3      990010         120816               NaN          NaN          NaN
# 4      990012         120816               NaN          NaN          NaN
#
#    5 Yr % Rank  1 Yr Return  3 Yr Return  5 Yr Return
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN

# %%
for element in Investment_id_based_features:
    submit[element]=submit[element].map(df2.set_index('index')[element])

# %%
for a in Advisor_Id_based_features:
    submit[a]=np.nan

# %%
for a in Advisor_Id_based_features:
    submit[a]=submit[a].map(df3.set_index('index')[a])

# %%
submit.fillna(0,inplace=True)

# %%
submit[submit['Code_5']!=0]
# Out:
#        Advisor_Id  Investment_Id  1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  \
# 0          990003         120816          5.0         67.0         60.0
# 1          990007         120821          5.0         67.0         60.0
# 2          990009         120816          5.0         67.0         60.0
# 3          990010         120816          5.0         67.0         60.0
# 4          990012         120816          5.0         67.0         60.0
# 5          990016         120821          5.0         67.0         60.0
# 6          990018         120816          5.0         67.0         60.0
# 7          990022         120816          5.0         67.0         60.0
# 8          990024         120816          5.0         67.0         60.0
# 9          990043         120816          5.0         67.0         60.0
# 10         990044         120816          5.0         67.0         60.0
# 11         990046         120816          5.0         67.0         60.0
# ...

# %%
y=submit['Transaction_Type']
submit=submit.drop('Transaction_Type',1)

# %%
#preparing data for the time dependent columns

# %%
submit.fillna(0,inplace=True)

# %%
import xgboost as xgb
#from xgboost.sklearn import XGBClassifier
#from sklearn import cross_validation, metrics 
params = {
    'eta': 0.05,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'binary:logistic',
    'scoring': 'accuracy',
    'silent': 0
}

# %%
first_model_train_cloumns=Investment_id_based_features+Advisor_Id_based_features

# %%
train=d1[first_model_train_cloumns]

# %%
y_train=d1['Transaction_Type']

# %%
dtrain = xgb.DMatrix(data=train, label=y_train)

# %%
model=xgb.train(params,dtrain)

# %%
train
# Out:
#         1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return  \
# 0               5.0         67.0         60.0     5.266910     6.034646
# 1               5.0         67.0         60.0     5.266910     6.034646
# 2               5.0         77.0         91.0     7.596880     5.414178
# 3               4.0         92.0         95.0    11.994344     5.192679
# 4               5.0         80.0         97.0    14.809882     4.827860
# 5               4.0         68.0         96.0     9.110319     3.367922
# 6               5.0         77.0         91.0     7.596880     5.414178
# 7               4.0         68.0         96.0     9.110319     3.367922
# 8               4.0         70.0         98.0     9.827977     3.330066
# 9               4.0         70.0         98.0     9.827977     3.330066
# 10              4.0         92.0         95.0    11.994344     5.192679
# 11              5.0         80.0         97.0    14.809882     4.827860
# ...

# %%
test=xgb.DMatrix(submit[first_model_train_cloumns])

# %%
submit[first_model_train_cloumns]
# Out:
#        1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return  \
# 0              5.0         67.0         60.0      5.26691     6.034646
# 1              5.0         67.0         60.0      5.26691     6.034646
# 2              5.0         67.0         60.0      5.26691     6.034646
# 3              5.0         67.0         60.0      5.26691     6.034646
# 4              5.0         67.0         60.0      5.26691     6.034646
# 5              5.0         67.0         60.0      5.26691     6.034646
# 6              5.0         67.0         60.0      5.26691     6.034646
# 7              5.0         67.0         60.0      5.26691     6.034646
# 8              5.0         67.0         60.0      5.26691     6.034646
# 9              5.0         67.0         60.0      5.26691     6.034646
# 10             5.0         67.0         60.0      5.26691     6.034646
# 11             5.0         67.0         60.0      5.26691     6.034646
# ...

# %%
y_pred=model.predict(test)

# %%
set(y_pred)
# Out:
# {0.48163325}

# %%
train
# Out:
#         1 Yr % Rank  3 Yr % Rank  5 Yr % Rank  1 Yr Return  3 Yr Return  \
# 0               5.0         67.0         60.0     5.266910     6.034646
# 1               5.0         67.0         60.0     5.266910     6.034646
# 2               5.0         77.0         91.0     7.596880     5.414178
# 3               4.0         92.0         95.0    11.994344     5.192679
# 4               5.0         80.0         97.0    14.809882     4.827860
# 5               4.0         68.0         96.0     9.110319     3.367922
# 6               5.0         77.0         91.0     7.596880     5.414178
# 7               4.0         68.0         96.0     9.110319     3.367922
# 8               4.0         70.0         98.0     9.827977     3.330066
# 9               4.0         70.0         98.0     9.827977     3.330066
# 10              4.0         92.0         95.0    11.994344     5.192679
# 11              5.0         80.0         97.0    14.809882     4.827860
# ...

# %%
submit.shape
# Out:
# (60209, 13)
